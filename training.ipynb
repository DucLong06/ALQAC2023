# %%
# set up environment
import os
from google.colab import drive
# Mount đến gdrive
drive.mount('/content/gdrive')

os.chdir('/content/gdrive/MyDrive/Colab Notebooks/ALQAC2023/')

# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# bot_telegram.py			   logs       README.md		test.py
# cache				   main.py    requirements.txt	training.ipynb
# data				   my_env.py  scripts		tune_alpha.py
# data_visualization_question.png    prompt.py  src		tune_training.py
# data_visualization_true_false.png  prompts    submit_task2.sh

# %%
# !pip install -r requirements.txt
# !nvidia-smi

# %%
# !python prompt.py --model "bigscience/mt0-xxl" --questions "data/new_data_102023/test.json" --articles "data/training/new_articles.json" --prompts "prompts/prompts_vn.json"

# %%
# !python prompt.py --model "bigscience/mt0-xxl" --questions "data/new_data_102023/train.json" --articles "data/training/new_articles.json" --prompts "prompts/prompts_vn.json" --compare "True" --cache ""

# %%
# !python prompt.py --model "t5-small" --questions "data/new_data_102023/train.json" --articles "data/training/new_articles.json" --prompts "prompts/prompts_vn.json" --compare "True" --cache "cache"
# Out:
# 0it [00:00, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# 2023-10-26 15:27:17.723673: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-26 15:27:17.723736: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
